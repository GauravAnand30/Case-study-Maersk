# %%
# !pip install simpy
# Out:
# Requirement already satisfied: simpy in c:\users\asus\anaconda3\anaconda33\lib\site-packages (4.1.1)

# %%
import simpy
import random
import csv
from datetime import datetime

# Constants
AVG_ARRIVAL_TIME = 5
NUM_CONTAINERS = 150
CRANE_TIME_PER_CONTAINER = 3
TRUCK_CYCLE_TIME = 6
NUM_BERTHS = 2
NUM_CRANES = 2
NUM_TRUCKS = 3

class ContainerTerminal:
  def __init__(self,env):
       self.env = env
       self.berths = simpy.Resource(env, capacity=NUM_BERTHS)
       self.quay_cranes = simpy.Resource(env, capacity=NUM_CRANES)
       self.trucks = simpy.Resource(env, capacity=NUM_TRUCKS)

class Logger:
  def __init__(self, filename):
    self.filename = filename
    with open(self.filename, 'w', newline='') as file:
      writer = csv.writer(file)
      writer.writerow(["Timestamp", "Simulation Time", "Event"])

  def log_event(self, env, message):
    with open(self.filename, 'a', newline='') as file:
      writer = csv.writer(file)
      writer.writerow([datetime.now(), f"{env.now:.2f}", message])
    print(f"{env.now:.2f}: {message}")

def vessel_process(env, terminal, logger, vessel_id):
    containers = NUM_CONTAINERS
    logger.log_event(env, f"Vessel {vessel_id} arrived with {containers} containers")

    with terminal.berths.request() as berth:
        yield berth
        logger.log_event(env, f"Vessel {vessel_id} berthed")

        with terminal.quay_cranes.request() as crane:
            yield crane
            logger.log_event(env, f"Quay crane assigned to Vessel {vessel_id}")

            while containers > 0:
                with terminal.trucks.request() as truck:
                    yield truck
                    yield env.timeout(CRANE_TIME_PER_CONTAINER)  # Time to move container to truck
                    containers -= 1
                    logger.log_event(env, f"Quay crane moved a container from Vessel {vessel_id} to truck. Remaining: {containers}")

                    yield env.timeout(TRUCK_CYCLE_TIME)  # Truck's round trip to yard
                    logger.log_event(env, f"After Dropping Truck returned from yard for Vessel {vessel_id}")

        logger.log_event(env, f"Quay crane released for Vessel {vessel_id}")

    logger.log_event(env, f"Vessel {vessel_id} unloaded and departed. Berth is now free.")


def vessel_generator(env, terminal, logger):
    vessel_id = 1
    while True:
        yield env.timeout(random.expovariate(1 / (AVG_ARRIVAL_TIME * 60)))  # Average 5 hours (300 minutes) between arrivals
        env.process(vessel_process(env, terminal, logger, vessel_id))
        vessel_id += 1

def run_simulation(env, simulation_time, logger):
    terminal = ContainerTerminal(env)
    env.process(vessel_generator(env, terminal, logger))
    logger.log_event(env, f"Starting simulation for {simulation_time} minutes")
    env.run(until=simulation_time)
    logger.log_event(env, "Simulation completed")

if __name__ == "__main__":
    try:
        SIMULATION_TIME = int(input("Enter simulation time in minutes: ")) 
        if SIMULATION_TIME <= 0:
            raise ValueError("Simulation time must be a positive integer.")
    except ValueError as e:
        print(f"Invalid input: {e}")
    else:
        env = simpy.Environment()
        logger = Logger("container_terminal_simulation.csv")
        run_simulation(env, SIMULATION_TIME, logger)
# Out:
# Enter simulation time in minutes: 3000
# 0.00: Starting simulation for 3000 minutes
# 49.94: Vessel 1 arrived with 150 containers
# 49.94: Vessel 1 berthed
# 49.94: Quay crane assigned to Vessel 1
# 52.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 149
# 58.94: After Dropping Truck returned from yard for Vessel 1
# 61.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 148
# 67.94: After Dropping Truck returned from yard for Vessel 1
# 70.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 147
# 76.94: After Dropping Truck returned from yard for Vessel 1
# 79.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 146
# 85.94: After Dropping Truck returned from yard for Vessel 1
# 88.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 145
# 94.94: After Dropping Truck returned from yard for Vessel 1
# 97.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 144
# 103.94: After Dropping Truck returned from yard for Vessel 1
# 106.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 143
# 112.94: After Dropping Truck returned from yard for Vessel 1
# 115.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 142
# 121.94: After Dropping Truck returned from yard for Vessel 1
# 124.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 141
# 130.94: After Dropping Truck returned from yard for Vessel 1
# 133.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 140
# 139.94: After Dropping Truck returned from yard for Vessel 1
# 142.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 139
# 148.94: After Dropping Truck returned from yard for Vessel 1
# 151.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 138
# 157.94: After Dropping Truck returned from yard for Vessel 1
# 160.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 137
# 166.94: After Dropping Truck returned from yard for Vessel 1
# 169.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 136
# 175.94: After Dropping Truck returned from yard for Vessel 1
# 178.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 135
# 184.94: After Dropping Truck returned from yard for Vessel 1
# 187.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 134
# 193.94: After Dropping Truck returned from yard for Vessel 1
# 196.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 133
# 202.94: After Dropping Truck returned from yard for Vessel 1
# 205.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 132
# 211.94: After Dropping Truck returned from yard for Vessel 1
# 214.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 131
# 220.94: After Dropping Truck returned from yard for Vessel 1
# 223.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 130
# 229.94: After Dropping Truck returned from yard for Vessel 1
# 232.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 129
# 238.94: After Dropping Truck returned from yard for Vessel 1
# 241.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 128
# 247.94: After Dropping Truck returned from yard for Vessel 1
# 250.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 127
# 256.94: After Dropping Truck returned from yard for Vessel 1
# 259.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 126
# 265.94: After Dropping Truck returned from yard for Vessel 1
# 268.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 125
# 274.94: After Dropping Truck returned from yard for Vessel 1
# 277.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 124
# 283.94: After Dropping Truck returned from yard for Vessel 1
# 286.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 123
# 292.94: After Dropping Truck returned from yard for Vessel 1
# 295.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 122
# 301.94: After Dropping Truck returned from yard for Vessel 1
# 304.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 121
# 310.94: After Dropping Truck returned from yard for Vessel 1
# 313.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 120
# 319.94: After Dropping Truck returned from yard for Vessel 1
# 322.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 119
# 328.94: After Dropping Truck returned from yard for Vessel 1
# 331.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 118
# 337.94: After Dropping Truck returned from yard for Vessel 1
# 340.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 117
# 346.94: After Dropping Truck returned from yard for Vessel 1
# 349.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 116
# 355.94: After Dropping Truck returned from yard for Vessel 1
# 358.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 115
# 364.94: After Dropping Truck returned from yard for Vessel 1
# 367.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 114
# 373.94: After Dropping Truck returned from yard for Vessel 1
# 376.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 113
# 382.94: After Dropping Truck returned from yard for Vessel 1
# 385.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 112
# 391.94: After Dropping Truck returned from yard for Vessel 1
# 394.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 111
# 400.94: After Dropping Truck returned from yard for Vessel 1
# 403.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 110
# 409.94: After Dropping Truck returned from yard for Vessel 1
# 412.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 109
# 418.94: After Dropping Truck returned from yard for Vessel 1
# 421.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 108
# 427.94: After Dropping Truck returned from yard for Vessel 1
# 430.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 107
# 436.94: After Dropping Truck returned from yard for Vessel 1
# 439.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 106
# 445.94: After Dropping Truck returned from yard for Vessel 1
# 448.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 105
# 454.94: After Dropping Truck returned from yard for Vessel 1
# 457.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 104
# 463.94: After Dropping Truck returned from yard for Vessel 1
# 466.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 103
# 472.94: After Dropping Truck returned from yard for Vessel 1
# 475.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 102
# 481.94: After Dropping Truck returned from yard for Vessel 1
# 484.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 101
# 490.94: After Dropping Truck returned from yard for Vessel 1
# 493.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 100
# 499.94: After Dropping Truck returned from yard for Vessel 1
# 502.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 99
# 508.94: After Dropping Truck returned from yard for Vessel 1
# 511.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 98
# 517.94: After Dropping Truck returned from yard for Vessel 1
# 520.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 97
# 526.94: After Dropping Truck returned from yard for Vessel 1
# 529.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 96
# 535.94: After Dropping Truck returned from yard for Vessel 1
# 538.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 95
# 544.94: After Dropping Truck returned from yard for Vessel 1
# 547.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 94
# 553.94: After Dropping Truck returned from yard for Vessel 1
# 556.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 93
# 562.94: After Dropping Truck returned from yard for Vessel 1
# 565.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 92
# 571.94: After Dropping Truck returned from yard for Vessel 1
# 574.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 91
# 580.94: After Dropping Truck returned from yard for Vessel 1
# 583.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 90
# 589.94: After Dropping Truck returned from yard for Vessel 1
# 592.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 89
# 598.94: After Dropping Truck returned from yard for Vessel 1
# 601.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 88
# 607.94: After Dropping Truck returned from yard for Vessel 1
# 610.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 87
# 616.94: After Dropping Truck returned from yard for Vessel 1
# 619.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 86
# 625.94: After Dropping Truck returned from yard for Vessel 1
# 628.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 85
# 634.94: After Dropping Truck returned from yard for Vessel 1
# 637.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 84
# 643.94: After Dropping Truck returned from yard for Vessel 1
# 646.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 83
# 652.94: After Dropping Truck returned from yard for Vessel 1
# 655.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 82
# 661.94: After Dropping Truck returned from yard for Vessel 1
# 664.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 81
# 670.94: After Dropping Truck returned from yard for Vessel 1
# 673.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 80
# 679.94: After Dropping Truck returned from yard for Vessel 1
# 682.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 79
# 688.94: After Dropping Truck returned from yard for Vessel 1
# 691.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 78
# 697.94: After Dropping Truck returned from yard for Vessel 1
# 700.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 77
# 706.94: After Dropping Truck returned from yard for Vessel 1
# 709.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 76
# 715.94: After Dropping Truck returned from yard for Vessel 1
# 718.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 75
# 724.94: After Dropping Truck returned from yard for Vessel 1
# 727.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 74
# 733.94: After Dropping Truck returned from yard for Vessel 1
# 736.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 73
# 742.94: After Dropping Truck returned from yard for Vessel 1
# 745.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 72
# 751.94: After Dropping Truck returned from yard for Vessel 1
# 754.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 71
# 760.94: After Dropping Truck returned from yard for Vessel 1
# 763.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 70
# 769.94: After Dropping Truck returned from yard for Vessel 1
# 772.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 69
# 778.94: After Dropping Truck returned from yard for Vessel 1
# 781.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 68
# 787.94: After Dropping Truck returned from yard for Vessel 1
# 790.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 67
# 796.94: After Dropping Truck returned from yard for Vessel 1
# 799.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 66
# 805.94: After Dropping Truck returned from yard for Vessel 1
# 808.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 65
# 814.94: After Dropping Truck returned from yard for Vessel 1
# 817.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 64
# 823.94: After Dropping Truck returned from yard for Vessel 1
# 826.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 63
# 829.17: Vessel 2 arrived with 150 containers
# 829.17: Vessel 2 berthed
# 829.17: Quay crane assigned to Vessel 2
# 832.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 149
# 832.94: After Dropping Truck returned from yard for Vessel 1
# 835.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 62
# 838.17: After Dropping Truck returned from yard for Vessel 2
# 841.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 148
# 841.94: After Dropping Truck returned from yard for Vessel 1
# 844.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 61
# 847.17: After Dropping Truck returned from yard for Vessel 2
# 850.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 147
# 850.94: After Dropping Truck returned from yard for Vessel 1
# 853.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 60
# 856.17: After Dropping Truck returned from yard for Vessel 2
# 859.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 146
# 859.94: After Dropping Truck returned from yard for Vessel 1
# 862.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 59
# 865.17: After Dropping Truck returned from yard for Vessel 2
# 868.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 145
# 868.94: After Dropping Truck returned from yard for Vessel 1
# 871.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 58
# 874.17: After Dropping Truck returned from yard for Vessel 2
# 877.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 144
# 877.94: After Dropping Truck returned from yard for Vessel 1
# 880.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 57
# 883.17: After Dropping Truck returned from yard for Vessel 2
# 886.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 143
# 886.94: After Dropping Truck returned from yard for Vessel 1
# 889.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 56
# 892.17: After Dropping Truck returned from yard for Vessel 2
# 895.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 142
# 895.94: After Dropping Truck returned from yard for Vessel 1
# 898.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 55
# 901.17: After Dropping Truck returned from yard for Vessel 2
# 904.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 141
# 904.94: After Dropping Truck returned from yard for Vessel 1
# 907.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 54
# 910.17: After Dropping Truck returned from yard for Vessel 2
# 913.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 140
# 913.94: After Dropping Truck returned from yard for Vessel 1
# 916.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 53
# 919.17: After Dropping Truck returned from yard for Vessel 2
# 922.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 139
# 922.94: After Dropping Truck returned from yard for Vessel 1
# 925.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 52
# 928.17: After Dropping Truck returned from yard for Vessel 2
# 931.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 138
# 931.94: After Dropping Truck returned from yard for Vessel 1
# 934.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 51
# 937.17: After Dropping Truck returned from yard for Vessel 2
# 940.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 137
# 940.94: After Dropping Truck returned from yard for Vessel 1
# 943.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 50
# 946.17: After Dropping Truck returned from yard for Vessel 2
# 949.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 136
# 949.94: After Dropping Truck returned from yard for Vessel 1
# 952.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 49
# 955.17: After Dropping Truck returned from yard for Vessel 2
# 958.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 135
# 958.94: After Dropping Truck returned from yard for Vessel 1
# 961.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 48
# 964.17: After Dropping Truck returned from yard for Vessel 2
# 967.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 134
# 967.94: After Dropping Truck returned from yard for Vessel 1
# 970.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 47
# 973.17: After Dropping Truck returned from yard for Vessel 2
# 976.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 133
# 976.94: After Dropping Truck returned from yard for Vessel 1
# 979.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 46
# 982.17: After Dropping Truck returned from yard for Vessel 2
# 985.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 132
# 985.94: After Dropping Truck returned from yard for Vessel 1
# 988.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 45
# 991.17: After Dropping Truck returned from yard for Vessel 2
# 994.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 131
# 994.94: After Dropping Truck returned from yard for Vessel 1
# 997.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 44
# 1000.17: After Dropping Truck returned from yard for Vessel 2
# 1003.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 130
# 1003.94: After Dropping Truck returned from yard for Vessel 1
# 1006.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 43
# 1009.17: After Dropping Truck returned from yard for Vessel 2
# 1012.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 129
# 1012.94: After Dropping Truck returned from yard for Vessel 1
# 1015.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 42
# 1018.17: After Dropping Truck returned from yard for Vessel 2
# 1021.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 128
# 1021.94: After Dropping Truck returned from yard for Vessel 1
# 1024.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 41
# 1027.17: After Dropping Truck returned from yard for Vessel 2
# 1030.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 127
# 1030.94: After Dropping Truck returned from yard for Vessel 1
# 1033.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 40
# 1036.17: After Dropping Truck returned from yard for Vessel 2
# 1039.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 126
# 1039.94: After Dropping Truck returned from yard for Vessel 1
# 1042.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 39
# 1045.17: After Dropping Truck returned from yard for Vessel 2
# 1048.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 125
# 1048.94: After Dropping Truck returned from yard for Vessel 1
# 1051.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 38
# 1054.17: After Dropping Truck returned from yard for Vessel 2
# 1057.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 124
# 1057.94: After Dropping Truck returned from yard for Vessel 1
# 1060.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 37
# 1063.17: After Dropping Truck returned from yard for Vessel 2
# 1066.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 123
# 1066.94: After Dropping Truck returned from yard for Vessel 1
# 1069.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 36
# 1072.17: After Dropping Truck returned from yard for Vessel 2
# 1075.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 122
# 1075.94: After Dropping Truck returned from yard for Vessel 1
# 1078.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 35
# 1081.17: After Dropping Truck returned from yard for Vessel 2
# 1084.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 121
# 1084.94: After Dropping Truck returned from yard for Vessel 1
# 1087.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 34
# 1090.17: After Dropping Truck returned from yard for Vessel 2
# 1093.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 120
# 1093.94: After Dropping Truck returned from yard for Vessel 1
# 1096.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 33
# 1099.17: After Dropping Truck returned from yard for Vessel 2
# 1102.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 119
# 1102.94: After Dropping Truck returned from yard for Vessel 1
# 1105.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 32
# 1108.17: After Dropping Truck returned from yard for Vessel 2
# 1111.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 118
# 1111.94: After Dropping Truck returned from yard for Vessel 1
# 1113.23: Vessel 3 arrived with 150 containers
# 1114.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 31
# 1117.17: After Dropping Truck returned from yard for Vessel 2
# 1120.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 117
# 1120.94: After Dropping Truck returned from yard for Vessel 1
# 1123.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 30
# 1126.17: After Dropping Truck returned from yard for Vessel 2
# 1129.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 116
# 1129.94: After Dropping Truck returned from yard for Vessel 1
# 1132.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 29
# 1135.17: After Dropping Truck returned from yard for Vessel 2
# 1138.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 115
# 1138.94: After Dropping Truck returned from yard for Vessel 1
# 1141.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 28
# 1144.17: After Dropping Truck returned from yard for Vessel 2
# 1147.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 114
# 1147.94: After Dropping Truck returned from yard for Vessel 1
# 1150.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 27
# 1153.17: After Dropping Truck returned from yard for Vessel 2
# 1156.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 113
# 1156.94: After Dropping Truck returned from yard for Vessel 1
# 1159.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 26
# 1162.17: After Dropping Truck returned from yard for Vessel 2
# 1165.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 112
# 1165.94: After Dropping Truck returned from yard for Vessel 1
# 1168.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 25
# 1171.17: After Dropping Truck returned from yard for Vessel 2
# 1174.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 111
# 1174.71: Vessel 4 arrived with 150 containers
# 1174.94: After Dropping Truck returned from yard for Vessel 1
# 1177.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 24
# 1180.17: After Dropping Truck returned from yard for Vessel 2
# 1183.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 110
# 1183.94: After Dropping Truck returned from yard for Vessel 1
# 1186.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 23
# 1189.17: After Dropping Truck returned from yard for Vessel 2
# 1192.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 109
# 1192.94: After Dropping Truck returned from yard for Vessel 1
# 1195.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 22
# 1198.17: After Dropping Truck returned from yard for Vessel 2
# 1201.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 108
# 1201.94: After Dropping Truck returned from yard for Vessel 1
# 1204.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 21
# 1207.17: After Dropping Truck returned from yard for Vessel 2
# 1210.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 107
# 1210.94: After Dropping Truck returned from yard for Vessel 1
# 1213.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 20
# 1216.17: After Dropping Truck returned from yard for Vessel 2
# 1219.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 106
# 1219.94: After Dropping Truck returned from yard for Vessel 1
# 1222.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 19
# 1225.17: After Dropping Truck returned from yard for Vessel 2
# 1228.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 105
# 1228.94: After Dropping Truck returned from yard for Vessel 1
# 1231.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 18
# 1234.17: After Dropping Truck returned from yard for Vessel 2
# 1237.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 104
# 1237.94: After Dropping Truck returned from yard for Vessel 1
# 1240.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 17
# 1243.17: After Dropping Truck returned from yard for Vessel 2
# 1246.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 103
# 1246.94: After Dropping Truck returned from yard for Vessel 1
# 1249.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 16
# 1252.17: After Dropping Truck returned from yard for Vessel 2
# 1255.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 102
# 1255.94: After Dropping Truck returned from yard for Vessel 1
# 1258.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 15
# 1261.17: After Dropping Truck returned from yard for Vessel 2
# 1264.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 101
# 1264.94: After Dropping Truck returned from yard for Vessel 1
# 1267.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 14
# 1270.17: After Dropping Truck returned from yard for Vessel 2
# 1273.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 100
# 1273.94: After Dropping Truck returned from yard for Vessel 1
# 1276.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 13
# 1279.17: After Dropping Truck returned from yard for Vessel 2
# 1282.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 99
# 1282.94: After Dropping Truck returned from yard for Vessel 1
# 1285.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 12
# 1288.17: After Dropping Truck returned from yard for Vessel 2
# 1291.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 98
# 1291.94: After Dropping Truck returned from yard for Vessel 1
# 1294.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 11
# 1297.17: After Dropping Truck returned from yard for Vessel 2
# 1300.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 97
# 1300.94: After Dropping Truck returned from yard for Vessel 1
# 1303.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 10
# 1306.17: After Dropping Truck returned from yard for Vessel 2
# 1309.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 96
# 1309.94: After Dropping Truck returned from yard for Vessel 1
# 1312.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 9
# 1315.17: After Dropping Truck returned from yard for Vessel 2
# 1318.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 95
# 1318.94: After Dropping Truck returned from yard for Vessel 1
# 1321.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 8
# 1324.17: After Dropping Truck returned from yard for Vessel 2
# 1327.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 94
# 1327.94: After Dropping Truck returned from yard for Vessel 1
# 1330.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 7
# 1333.17: After Dropping Truck returned from yard for Vessel 2
# 1336.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 93
# 1336.94: After Dropping Truck returned from yard for Vessel 1
# 1339.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 6
# 1342.17: After Dropping Truck returned from yard for Vessel 2
# 1345.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 92
# 1345.94: After Dropping Truck returned from yard for Vessel 1
# 1348.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 5
# 1351.17: After Dropping Truck returned from yard for Vessel 2
# 1354.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 91
# 1354.94: After Dropping Truck returned from yard for Vessel 1
# 1357.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 4
# 1360.17: After Dropping Truck returned from yard for Vessel 2
# 1363.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 90
# 1363.94: After Dropping Truck returned from yard for Vessel 1
# 1366.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 3
# 1369.17: After Dropping Truck returned from yard for Vessel 2
# 1372.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 89
# 1372.94: After Dropping Truck returned from yard for Vessel 1
# 1375.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 2
# 1378.17: After Dropping Truck returned from yard for Vessel 2
# 1381.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 88
# 1381.94: After Dropping Truck returned from yard for Vessel 1
# 1384.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 1
# 1387.17: After Dropping Truck returned from yard for Vessel 2
# 1390.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 87
# 1390.94: After Dropping Truck returned from yard for Vessel 1
# 1393.94: Quay crane moved a container from Vessel 1 to truck. Remaining: 0
# 1396.17: After Dropping Truck returned from yard for Vessel 2
# 1399.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 86
# 1399.94: After Dropping Truck returned from yard for Vessel 1
# 1399.94: Quay crane released for Vessel 1
# 1399.94: Vessel 1 unloaded and departed. Berth is now free.
# 1399.94: Vessel 3 berthed
# 1399.94: Quay crane assigned to Vessel 3
# 1402.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 149
# 1405.17: After Dropping Truck returned from yard for Vessel 2
# 1408.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 85
# 1408.94: After Dropping Truck returned from yard for Vessel 3
# 1411.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 148
# 1414.17: After Dropping Truck returned from yard for Vessel 2
# 1417.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 84
# 1417.94: After Dropping Truck returned from yard for Vessel 3
# 1420.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 147
# 1423.17: After Dropping Truck returned from yard for Vessel 2
# 1426.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 83
# 1426.94: After Dropping Truck returned from yard for Vessel 3
# 1429.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 146
# 1432.17: After Dropping Truck returned from yard for Vessel 2
# 1435.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 82
# 1435.94: After Dropping Truck returned from yard for Vessel 3
# 1438.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 145
# 1441.17: After Dropping Truck returned from yard for Vessel 2
# 1444.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 81
# 1444.94: After Dropping Truck returned from yard for Vessel 3
# 1447.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 144
# 1450.17: After Dropping Truck returned from yard for Vessel 2
# 1453.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 80
# 1453.94: After Dropping Truck returned from yard for Vessel 3
# 1456.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 143
# 1459.17: After Dropping Truck returned from yard for Vessel 2
# 1462.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 79
# 1462.94: After Dropping Truck returned from yard for Vessel 3
# 1465.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 142
# 1468.17: After Dropping Truck returned from yard for Vessel 2
# 1471.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 78
# 1471.94: After Dropping Truck returned from yard for Vessel 3
# 1474.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 141
# 1477.17: After Dropping Truck returned from yard for Vessel 2
# 1480.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 77
# 1480.94: After Dropping Truck returned from yard for Vessel 3
# 1483.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 140
# 1486.17: After Dropping Truck returned from yard for Vessel 2
# 1489.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 76
# 1489.94: After Dropping Truck returned from yard for Vessel 3
# 1492.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 139
# 1495.17: After Dropping Truck returned from yard for Vessel 2
# 1498.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 75
# 1498.94: After Dropping Truck returned from yard for Vessel 3
# 1501.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 138
# 1504.17: After Dropping Truck returned from yard for Vessel 2
# 1507.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 74
# 1507.94: After Dropping Truck returned from yard for Vessel 3
# 1510.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 137
# 1513.17: After Dropping Truck returned from yard for Vessel 2
# 1516.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 73
# 1516.94: After Dropping Truck returned from yard for Vessel 3
# 1519.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 136
# 1522.17: After Dropping Truck returned from yard for Vessel 2
# 1525.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 72
# 1525.94: After Dropping Truck returned from yard for Vessel 3
# 1528.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 135
# 1531.17: After Dropping Truck returned from yard for Vessel 2
# 1534.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 71
# 1534.94: After Dropping Truck returned from yard for Vessel 3
# 1537.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 134
# 1540.17: After Dropping Truck returned from yard for Vessel 2
# 1543.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 70
# 1543.94: After Dropping Truck returned from yard for Vessel 3
# 1546.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 133
# 1549.17: After Dropping Truck returned from yard for Vessel 2
# 1552.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 69
# 1552.94: After Dropping Truck returned from yard for Vessel 3
# 1555.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 132
# 1558.17: After Dropping Truck returned from yard for Vessel 2
# 1561.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 68
# 1561.94: After Dropping Truck returned from yard for Vessel 3
# 1564.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 131
# 1566.45: Vessel 5 arrived with 150 containers
# 1567.17: After Dropping Truck returned from yard for Vessel 2
# 1570.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 67
# 1570.94: After Dropping Truck returned from yard for Vessel 3
# 1573.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 130
# 1576.17: After Dropping Truck returned from yard for Vessel 2
# 1579.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 66
# 1579.94: After Dropping Truck returned from yard for Vessel 3
# 1582.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 129
# 1585.17: After Dropping Truck returned from yard for Vessel 2
# 1588.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 65
# 1588.94: After Dropping Truck returned from yard for Vessel 3
# 1591.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 128
# 1594.17: After Dropping Truck returned from yard for Vessel 2
# 1597.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 64
# 1597.94: After Dropping Truck returned from yard for Vessel 3
# 1600.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 127
# 1603.17: After Dropping Truck returned from yard for Vessel 2
# 1606.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 63
# 1606.94: After Dropping Truck returned from yard for Vessel 3
# 1609.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 126
# 1612.17: After Dropping Truck returned from yard for Vessel 2
# 1615.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 62
# 1615.94: After Dropping Truck returned from yard for Vessel 3
# 1618.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 125
# 1621.17: After Dropping Truck returned from yard for Vessel 2
# 1624.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 61
# 1624.94: After Dropping Truck returned from yard for Vessel 3
# 1627.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 124
# 1630.17: After Dropping Truck returned from yard for Vessel 2
# 1633.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 60
# 1633.94: After Dropping Truck returned from yard for Vessel 3
# 1636.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 123
# 1639.17: After Dropping Truck returned from yard for Vessel 2
# 1642.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 59
# 1642.94: After Dropping Truck returned from yard for Vessel 3
# 1645.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 122
# 1648.17: After Dropping Truck returned from yard for Vessel 2
# 1651.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 58
# 1651.94: After Dropping Truck returned from yard for Vessel 3
# 1654.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 121
# 1657.17: After Dropping Truck returned from yard for Vessel 2
# 1660.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 57
# 1660.94: After Dropping Truck returned from yard for Vessel 3
# 1663.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 120
# 1666.17: After Dropping Truck returned from yard for Vessel 2
# 1669.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 56
# 1669.94: After Dropping Truck returned from yard for Vessel 3
# 1672.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 119
# 1675.17: After Dropping Truck returned from yard for Vessel 2
# 1678.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 55
# 1678.94: After Dropping Truck returned from yard for Vessel 3
# 1681.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 118
# 1684.17: After Dropping Truck returned from yard for Vessel 2
# 1687.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 54
# 1687.94: After Dropping Truck returned from yard for Vessel 3
# 1690.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 117
# 1693.17: After Dropping Truck returned from yard for Vessel 2
# 1696.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 53
# 1696.94: After Dropping Truck returned from yard for Vessel 3
# 1699.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 116
# 1702.17: After Dropping Truck returned from yard for Vessel 2
# 1705.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 52
# 1705.94: After Dropping Truck returned from yard for Vessel 3
# 1708.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 115
# 1711.17: After Dropping Truck returned from yard for Vessel 2
# 1714.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 51
# 1714.94: After Dropping Truck returned from yard for Vessel 3
# 1717.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 114
# 1720.17: After Dropping Truck returned from yard for Vessel 2
# 1723.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 50
# 1723.94: After Dropping Truck returned from yard for Vessel 3
# 1726.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 113
# 1729.17: After Dropping Truck returned from yard for Vessel 2
# 1732.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 49
# 1732.94: After Dropping Truck returned from yard for Vessel 3
# 1735.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 112
# 1738.17: After Dropping Truck returned from yard for Vessel 2
# 1741.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 48
# 1741.94: After Dropping Truck returned from yard for Vessel 3
# 1744.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 111
# 1747.17: After Dropping Truck returned from yard for Vessel 2
# 1750.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 47
# 1750.94: After Dropping Truck returned from yard for Vessel 3
# 1753.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 110
# 1756.17: After Dropping Truck returned from yard for Vessel 2
# 1759.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 46
# 1759.94: After Dropping Truck returned from yard for Vessel 3
# 1762.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 109
# 1765.17: After Dropping Truck returned from yard for Vessel 2
# 1768.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 45
# 1768.94: After Dropping Truck returned from yard for Vessel 3
# 1771.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 108
# 1774.17: After Dropping Truck returned from yard for Vessel 2
# 1777.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 44
# 1777.94: After Dropping Truck returned from yard for Vessel 3
# 1780.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 107
# 1783.17: After Dropping Truck returned from yard for Vessel 2
# 1786.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 43
# 1786.94: After Dropping Truck returned from yard for Vessel 3
# 1789.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 106
# 1792.17: After Dropping Truck returned from yard for Vessel 2
# 1795.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 42
# 1795.94: After Dropping Truck returned from yard for Vessel 3
# 1798.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 105
# 1801.17: After Dropping Truck returned from yard for Vessel 2
# 1804.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 41
# 1804.94: After Dropping Truck returned from yard for Vessel 3
# 1807.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 104
# 1810.17: After Dropping Truck returned from yard for Vessel 2
# 1813.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 40
# 1813.94: After Dropping Truck returned from yard for Vessel 3
# 1816.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 103
# 1819.17: After Dropping Truck returned from yard for Vessel 2
# 1822.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 39
# 1822.94: After Dropping Truck returned from yard for Vessel 3
# 1825.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 102
# 1828.17: After Dropping Truck returned from yard for Vessel 2
# 1831.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 38
# 1831.94: After Dropping Truck returned from yard for Vessel 3
# 1834.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 101
# 1837.17: After Dropping Truck returned from yard for Vessel 2
# 1840.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 37
# 1840.94: After Dropping Truck returned from yard for Vessel 3
# 1843.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 100
# 1846.17: After Dropping Truck returned from yard for Vessel 2
# 1849.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 36
# 1849.94: After Dropping Truck returned from yard for Vessel 3
# 1852.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 99
# 1855.17: After Dropping Truck returned from yard for Vessel 2
# 1858.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 35
# 1858.94: After Dropping Truck returned from yard for Vessel 3
# 1861.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 98
# 1864.17: After Dropping Truck returned from yard for Vessel 2
# 1867.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 34
# 1867.94: After Dropping Truck returned from yard for Vessel 3
# 1870.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 97
# 1873.17: After Dropping Truck returned from yard for Vessel 2
# 1876.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 33
# 1876.94: After Dropping Truck returned from yard for Vessel 3
# 1879.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 96
# 1882.17: After Dropping Truck returned from yard for Vessel 2
# 1885.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 32
# 1885.94: After Dropping Truck returned from yard for Vessel 3
# 1888.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 95
# 1891.17: After Dropping Truck returned from yard for Vessel 2
# 1894.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 31
# 1894.94: After Dropping Truck returned from yard for Vessel 3
# 1897.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 94
# 1900.17: After Dropping Truck returned from yard for Vessel 2
# 1903.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 30
# 1903.94: After Dropping Truck returned from yard for Vessel 3
# 1906.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 93
# 1909.17: After Dropping Truck returned from yard for Vessel 2
# 1912.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 29
# 1912.94: After Dropping Truck returned from yard for Vessel 3
# 1915.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 92
# 1918.17: After Dropping Truck returned from yard for Vessel 2
# 1921.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 28
# 1921.94: After Dropping Truck returned from yard for Vessel 3
# 1924.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 91
# 1927.17: After Dropping Truck returned from yard for Vessel 2
# 1930.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 27
# 1930.94: After Dropping Truck returned from yard for Vessel 3
# 1933.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 90
# 1936.17: After Dropping Truck returned from yard for Vessel 2
# 1939.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 26
# 1939.94: After Dropping Truck returned from yard for Vessel 3
# 1942.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 89
# 1945.17: After Dropping Truck returned from yard for Vessel 2
# 1948.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 25
# 1948.94: After Dropping Truck returned from yard for Vessel 3
# 1951.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 88
# 1954.17: After Dropping Truck returned from yard for Vessel 2
# 1957.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 24
# 1957.94: After Dropping Truck returned from yard for Vessel 3
# 1960.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 87
# 1963.17: After Dropping Truck returned from yard for Vessel 2
# 1966.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 23
# 1966.94: After Dropping Truck returned from yard for Vessel 3
# 1969.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 86
# 1972.17: After Dropping Truck returned from yard for Vessel 2
# 1975.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 22
# 1975.94: After Dropping Truck returned from yard for Vessel 3
# 1978.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 85
# 1981.17: After Dropping Truck returned from yard for Vessel 2
# 1984.17: Quay crane moved a container from Vessel 2 to truck. Remaining: 21
# 1984.94: After Dropping Truck returned from yard for Vessel 3
# 1987.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 84
# ...
# 2488.94: After Dropping Truck returned from yard for Vessel 3
# 2491.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 28
# 2494.17: After Dropping Truck returned from yard for Vessel 4
# 2497.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 114
# 2497.94: After Dropping Truck returned from yard for Vessel 3
# 2500.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 27
# 2503.17: After Dropping Truck returned from yard for Vessel 4
# 2506.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 113
# 2506.94: After Dropping Truck returned from yard for Vessel 3
# 2509.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 26
# 2512.17: After Dropping Truck returned from yard for Vessel 4
# 2515.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 112
# 2515.94: After Dropping Truck returned from yard for Vessel 3
# 2518.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 25
# 2521.17: After Dropping Truck returned from yard for Vessel 4
# 2524.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 111
# 2524.94: After Dropping Truck returned from yard for Vessel 3
# 2527.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 24
# 2530.17: After Dropping Truck returned from yard for Vessel 4
# 2533.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 110
# 2533.94: After Dropping Truck returned from yard for Vessel 3
# 2536.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 23
# 2539.17: After Dropping Truck returned from yard for Vessel 4
# 2542.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 109
# 2542.94: After Dropping Truck returned from yard for Vessel 3
# 2545.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 22
# 2548.17: After Dropping Truck returned from yard for Vessel 4
# 2551.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 108
# 2551.94: After Dropping Truck returned from yard for Vessel 3
# 2554.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 21
# 2557.17: After Dropping Truck returned from yard for Vessel 4
# 2560.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 107
# 2560.94: After Dropping Truck returned from yard for Vessel 3
# 2563.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 20
# 2566.17: After Dropping Truck returned from yard for Vessel 4
# 2569.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 106
# 2569.94: After Dropping Truck returned from yard for Vessel 3
# 2572.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 19
# 2575.17: After Dropping Truck returned from yard for Vessel 4
# 2577.84: Vessel 9 arrived with 150 containers
# 2578.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 105
# 2578.94: After Dropping Truck returned from yard for Vessel 3
# 2581.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 18
# 2584.17: After Dropping Truck returned from yard for Vessel 4
# 2587.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 104
# 2587.94: After Dropping Truck returned from yard for Vessel 3
# 2590.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 17
# 2593.17: After Dropping Truck returned from yard for Vessel 4
# 2596.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 103
# 2596.94: After Dropping Truck returned from yard for Vessel 3
# 2599.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 16
# 2602.17: After Dropping Truck returned from yard for Vessel 4
# 2605.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 102
# 2605.94: After Dropping Truck returned from yard for Vessel 3
# 2608.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 15
# 2611.17: After Dropping Truck returned from yard for Vessel 4
# 2614.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 101
# 2614.94: After Dropping Truck returned from yard for Vessel 3
# 2617.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 14
# 2620.17: After Dropping Truck returned from yard for Vessel 4
# 2623.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 100
# 2623.94: After Dropping Truck returned from yard for Vessel 3
# 2626.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 13
# 2629.17: After Dropping Truck returned from yard for Vessel 4
# 2632.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 99
# 2632.94: After Dropping Truck returned from yard for Vessel 3
# 2635.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 12
# 2638.17: After Dropping Truck returned from yard for Vessel 4
# 2641.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 98
# 2641.94: After Dropping Truck returned from yard for Vessel 3
# 2644.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 11
# 2647.17: After Dropping Truck returned from yard for Vessel 4
# 2650.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 97
# 2650.94: After Dropping Truck returned from yard for Vessel 3
# 2653.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 10
# 2656.17: After Dropping Truck returned from yard for Vessel 4
# 2659.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 96
# 2659.94: After Dropping Truck returned from yard for Vessel 3
# 2662.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 9
# 2665.17: After Dropping Truck returned from yard for Vessel 4
# 2668.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 95
# 2668.94: After Dropping Truck returned from yard for Vessel 3
# 2671.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 8
# 2674.17: After Dropping Truck returned from yard for Vessel 4
# 2677.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 94
# 2677.94: After Dropping Truck returned from yard for Vessel 3
# 2680.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 7
# 2683.17: After Dropping Truck returned from yard for Vessel 4
# 2686.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 93
# 2686.94: After Dropping Truck returned from yard for Vessel 3
# 2689.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 6
# 2692.17: After Dropping Truck returned from yard for Vessel 4
# 2695.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 92
# 2695.94: After Dropping Truck returned from yard for Vessel 3
# 2698.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 5
# 2701.17: After Dropping Truck returned from yard for Vessel 4
# 2704.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 91
# 2704.94: After Dropping Truck returned from yard for Vessel 3
# 2707.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 4
# 2710.17: After Dropping Truck returned from yard for Vessel 4
# 2713.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 90
# 2713.94: After Dropping Truck returned from yard for Vessel 3
# 2716.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 3
# 2719.17: After Dropping Truck returned from yard for Vessel 4
# 2722.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 89
# 2722.94: After Dropping Truck returned from yard for Vessel 3
# 2725.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 2
# 2728.17: After Dropping Truck returned from yard for Vessel 4
# 2731.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 88
# 2731.94: After Dropping Truck returned from yard for Vessel 3
# 2734.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 1
# 2737.17: After Dropping Truck returned from yard for Vessel 4
# 2740.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 87
# 2740.94: After Dropping Truck returned from yard for Vessel 3
# 2743.94: Quay crane moved a container from Vessel 3 to truck. Remaining: 0
# 2746.17: After Dropping Truck returned from yard for Vessel 4
# 2749.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 86
# 2749.94: After Dropping Truck returned from yard for Vessel 3
# 2749.94: Quay crane released for Vessel 3
# 2749.94: Vessel 3 unloaded and departed. Berth is now free.
# 2749.94: Vessel 5 berthed
# 2749.94: Quay crane assigned to Vessel 5
# 2752.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 149
# 2755.17: After Dropping Truck returned from yard for Vessel 4
# 2758.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 85
# 2758.94: After Dropping Truck returned from yard for Vessel 5
# 2761.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 148
# 2764.17: After Dropping Truck returned from yard for Vessel 4
# 2767.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 84
# 2767.94: After Dropping Truck returned from yard for Vessel 5
# 2770.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 147
# 2773.17: After Dropping Truck returned from yard for Vessel 4
# 2776.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 83
# 2776.94: After Dropping Truck returned from yard for Vessel 5
# 2779.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 146
# 2782.17: After Dropping Truck returned from yard for Vessel 4
# 2785.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 82
# 2785.94: After Dropping Truck returned from yard for Vessel 5
# 2788.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 145
# 2791.17: After Dropping Truck returned from yard for Vessel 4
# 2794.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 81
# 2794.94: After Dropping Truck returned from yard for Vessel 5
# 2797.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 144
# 2800.17: After Dropping Truck returned from yard for Vessel 4
# 2803.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 80
# 2803.94: After Dropping Truck returned from yard for Vessel 5
# 2806.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 143
# 2809.17: After Dropping Truck returned from yard for Vessel 4
# 2812.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 79
# 2812.94: After Dropping Truck returned from yard for Vessel 5
# 2815.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 142
# 2818.17: After Dropping Truck returned from yard for Vessel 4
# 2821.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 78
# 2821.94: After Dropping Truck returned from yard for Vessel 5
# 2824.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 141
# 2827.17: After Dropping Truck returned from yard for Vessel 4
# 2830.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 77
# 2830.94: After Dropping Truck returned from yard for Vessel 5
# 2833.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 140
# 2836.17: After Dropping Truck returned from yard for Vessel 4
# 2839.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 76
# 2839.94: After Dropping Truck returned from yard for Vessel 5
# 2842.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 139
# 2845.17: After Dropping Truck returned from yard for Vessel 4
# 2848.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 75
# 2848.94: After Dropping Truck returned from yard for Vessel 5
# 2851.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 138
# 2854.17: After Dropping Truck returned from yard for Vessel 4
# 2857.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 74
# 2857.94: After Dropping Truck returned from yard for Vessel 5
# 2860.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 137
# 2863.17: After Dropping Truck returned from yard for Vessel 4
# 2866.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 73
# 2866.94: After Dropping Truck returned from yard for Vessel 5
# 2869.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 136
# 2872.17: After Dropping Truck returned from yard for Vessel 4
# 2875.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 72
# 2875.94: After Dropping Truck returned from yard for Vessel 5
# 2878.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 135
# 2881.17: After Dropping Truck returned from yard for Vessel 4
# 2884.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 71
# 2884.94: After Dropping Truck returned from yard for Vessel 5
# 2887.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 134
# 2890.17: After Dropping Truck returned from yard for Vessel 4
# 2893.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 70
# 2893.94: After Dropping Truck returned from yard for Vessel 5
# 2896.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 133
# 2899.17: After Dropping Truck returned from yard for Vessel 4
# 2902.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 69
# 2902.94: After Dropping Truck returned from yard for Vessel 5
# 2905.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 132
# 2908.17: After Dropping Truck returned from yard for Vessel 4
# 2911.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 68
# 2911.94: After Dropping Truck returned from yard for Vessel 5
# 2914.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 131
# 2917.17: After Dropping Truck returned from yard for Vessel 4
# 2920.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 67
# 2920.94: After Dropping Truck returned from yard for Vessel 5
# 2923.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 130
# 2926.17: After Dropping Truck returned from yard for Vessel 4
# 2929.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 66
# 2929.94: After Dropping Truck returned from yard for Vessel 5
# 2932.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 129
# 2935.17: After Dropping Truck returned from yard for Vessel 4
# 2938.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 65
# 2938.94: After Dropping Truck returned from yard for Vessel 5
# 2941.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 128
# 2944.17: After Dropping Truck returned from yard for Vessel 4
# 2947.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 64
# 2947.94: After Dropping Truck returned from yard for Vessel 5
# 2950.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 127
# 2953.17: After Dropping Truck returned from yard for Vessel 4
# 2956.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 63
# 2956.94: After Dropping Truck returned from yard for Vessel 5
# 2959.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 126
# 2962.17: After Dropping Truck returned from yard for Vessel 4
# 2965.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 62
# 2965.94: After Dropping Truck returned from yard for Vessel 5
# 2968.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 125
# 2971.17: After Dropping Truck returned from yard for Vessel 4
# 2974.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 61
# 2974.94: After Dropping Truck returned from yard for Vessel 5
# 2977.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 124
# 2980.17: After Dropping Truck returned from yard for Vessel 4
# 2983.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 60
# 2983.94: After Dropping Truck returned from yard for Vessel 5
# 2986.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 123
# 2989.17: After Dropping Truck returned from yard for Vessel 4
# 2992.17: Quay crane moved a container from Vessel 4 to truck. Remaining: 59
# 2992.94: After Dropping Truck returned from yard for Vessel 5
# 2995.34: Vessel 10 arrived with 150 containers
# 2995.94: Quay crane moved a container from Vessel 5 to truck. Remaining: 122
# 2998.17: After Dropping Truck returned from yard for Vessel 4
# 3000.00: Simulation completed
