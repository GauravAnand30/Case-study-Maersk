# %% [markdown]
# **Simulating a container terminal using SimPy**

# %%
# !pip install simpy
# Out:
# Collecting simpy
#   Downloading simpy-4.1.1-py3-none-any.whl (27 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.1.1

# %%
import simpy
import random
import csv
from datetime import datetime

# Constants
AVG_ARRIVAL_TIME = 5
NUM_CONTAINERS = 150
CRANE_TIME_PER_CONTAINER = 3
TRUCK_CYCLE_TIME = 6
NUM_BERTHS = 2
NUM_CRANES = 2
NUM_TRUCKS = 3

class ContainerTerminal:
  def __init__(self,env):
       self.env = env
       self.berths = simpy.Resource(env, capacity=NUM_BERTHS)
       self.quay_cranes = simpy.Resource(env, capacity=NUM_CRANES)
       self.trucks = simpy.Resource(env, capacity=NUM_TRUCKS)

class Logger:
  def __init__(self, filename):
    self.filename = filename
    with open(self.filename, 'w', newline='') as file:
      writer = csv.writer(file)
      writer.writerow(["Timestamp", "Simulation Time", "Event"])

  def log_event(self, env, message):
    with open(self.filename, 'a', newline='') as file:
      writer = csv.writer(file)
      writer.writerow([datetime.now(), f"{env.now:.2f}", message])
    print(f"{env.now:.2f}: {message}")

def vessel_process(env, terminal, logger, vessel_id):
    containers = NUM_CONTAINERS
    logger.log_event(env, f"Vessel {vessel_id} arrived with {containers} containers")

    with terminal.berths.request() as berth:
        yield berth
        logger.log_event(env, f"Vessel {vessel_id} berthed")

        with terminal.quay_cranes.request() as crane:
            yield crane
            logger.log_event(env, f"Quay crane assigned to Vessel {vessel_id}")

            while containers > 0:
                with terminal.trucks.request() as truck:
                    yield truck
                    yield env.timeout(CRANE_TIME_PER_CONTAINER)  # Time to move container to truck
                    containers -= 1
                    logger.log_event(env, f"Quay crane moved a container from Vessel {vessel_id} to truck. Remaining: {containers}")

                    yield env.timeout(TRUCK_CYCLE_TIME)  # Truck's round trip to yard
                    logger.log_event(env, f"After Dropping Truck returned from yard for Vessel {vessel_id}")

        logger.log_event(env, f"Quay crane released for Vessel {vessel_id}")

    logger.log_event(env, f"Vessel {vessel_id} unloaded and departed. Berth is now free.")


def vessel_generator(env, terminal, logger):
    vessel_id = 1
    while True:
        yield env.timeout(random.expovariate(1 / (AVG_ARRIVAL_TIME * 60)))  # Average 5 hours (300 minutes) between arrivals
        env.process(vessel_process(env, terminal, logger, vessel_id))
        vessel_id += 1

def run_simulation(env, simulation_time, logger):
    terminal = ContainerTerminal(env)
    env.process(vessel_generator(env, terminal, logger))
    logger.log_event(env, f"Starting simulation for {simulation_time} minutes")
    env.run(until=simulation_time)
    logger.log_event(env, "Simulation completed")

if __name__ == "__main__":
    try:
        SIMULATION_TIME = int(input("Enter simulation time in minutes: "))
        if SIMULATION_TIME <= 0:
            raise ValueError("Simulation time must be a positive integer.")
    except ValueError as e:
        print(f"Invalid input: {e}")
    else:
        env = simpy.Environment()
        logger = Logger("container_terminal_simulation.csv")
        run_simulation(env, SIMULATION_TIME, logger)
# Out:
# Enter simulation time in minutes: 3000
# 0.00: Starting simulation for 3000 minutes
# 29.11: Vessel 1 arrived with 150 containers
# 29.11: Vessel 1 berthed
# 29.11: Quay crane assigned to Vessel 1
# 32.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 149
# 38.11: After Dropping Truck returned from yard for Vessel 1
# 41.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 148
# 47.11: After Dropping Truck returned from yard for Vessel 1
# 50.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 147
# 56.11: After Dropping Truck returned from yard for Vessel 1
# 59.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 146
# 65.11: After Dropping Truck returned from yard for Vessel 1
# 68.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 145
# 74.11: After Dropping Truck returned from yard for Vessel 1
# 77.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 144
# 83.11: After Dropping Truck returned from yard for Vessel 1
# 86.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 143
# 92.11: After Dropping Truck returned from yard for Vessel 1
# 95.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 142
# 101.11: After Dropping Truck returned from yard for Vessel 1
# 104.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 141
# 110.11: After Dropping Truck returned from yard for Vessel 1
# 113.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 140
# 119.11: After Dropping Truck returned from yard for Vessel 1
# 122.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 139
# 128.11: After Dropping Truck returned from yard for Vessel 1
# 131.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 138
# 137.11: After Dropping Truck returned from yard for Vessel 1
# 140.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 137
# 146.11: After Dropping Truck returned from yard for Vessel 1
# 149.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 136
# 155.11: After Dropping Truck returned from yard for Vessel 1
# 158.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 135
# 164.11: After Dropping Truck returned from yard for Vessel 1
# 167.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 134
# 173.11: After Dropping Truck returned from yard for Vessel 1
# 176.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 133
# 182.11: After Dropping Truck returned from yard for Vessel 1
# 185.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 132
# 191.11: After Dropping Truck returned from yard for Vessel 1
# 194.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 131
# 200.11: After Dropping Truck returned from yard for Vessel 1
# 203.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 130
# 209.11: After Dropping Truck returned from yard for Vessel 1
# 212.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 129
# 218.11: After Dropping Truck returned from yard for Vessel 1
# 221.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 128
# 227.11: After Dropping Truck returned from yard for Vessel 1
# 230.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 127
# 236.11: After Dropping Truck returned from yard for Vessel 1
# 239.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 126
# 245.11: After Dropping Truck returned from yard for Vessel 1
# 248.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 125
# 254.11: After Dropping Truck returned from yard for Vessel 1
# 257.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 124
# 263.11: After Dropping Truck returned from yard for Vessel 1
# 266.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 123
# 272.11: After Dropping Truck returned from yard for Vessel 1
# 275.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 122
# 281.11: After Dropping Truck returned from yard for Vessel 1
# 284.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 121
# 290.11: After Dropping Truck returned from yard for Vessel 1
# 293.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 120
# 299.11: After Dropping Truck returned from yard for Vessel 1
# 302.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 119
# 308.11: After Dropping Truck returned from yard for Vessel 1
# 311.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 118
# 317.11: After Dropping Truck returned from yard for Vessel 1
# 320.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 117
# 326.11: After Dropping Truck returned from yard for Vessel 1
# 329.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 116
# 335.11: After Dropping Truck returned from yard for Vessel 1
# 338.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 115
# 344.11: After Dropping Truck returned from yard for Vessel 1
# 347.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 114
# 353.11: After Dropping Truck returned from yard for Vessel 1
# 356.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 113
# 362.11: After Dropping Truck returned from yard for Vessel 1
# 365.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 112
# 371.11: After Dropping Truck returned from yard for Vessel 1
# 374.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 111
# 380.11: After Dropping Truck returned from yard for Vessel 1
# 383.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 110
# 389.11: After Dropping Truck returned from yard for Vessel 1
# 392.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 109
# 398.11: After Dropping Truck returned from yard for Vessel 1
# 401.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 108
# 407.11: After Dropping Truck returned from yard for Vessel 1
# 410.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 107
# 416.11: After Dropping Truck returned from yard for Vessel 1
# 419.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 106
# 425.11: After Dropping Truck returned from yard for Vessel 1
# 428.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 105
# 434.11: After Dropping Truck returned from yard for Vessel 1
# 437.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 104
# 443.11: After Dropping Truck returned from yard for Vessel 1
# 446.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 103
# 452.11: After Dropping Truck returned from yard for Vessel 1
# 455.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 102
# 461.11: After Dropping Truck returned from yard for Vessel 1
# 464.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 101
# 470.11: After Dropping Truck returned from yard for Vessel 1
# 473.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 100
# 479.11: After Dropping Truck returned from yard for Vessel 1
# 482.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 99
# 488.11: After Dropping Truck returned from yard for Vessel 1
# 491.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 98
# 497.11: After Dropping Truck returned from yard for Vessel 1
# 500.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 97
# 506.11: After Dropping Truck returned from yard for Vessel 1
# 509.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 96
# 515.11: After Dropping Truck returned from yard for Vessel 1
# 518.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 95
# 524.11: After Dropping Truck returned from yard for Vessel 1
# 527.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 94
# 533.11: After Dropping Truck returned from yard for Vessel 1
# 536.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 93
# 542.11: After Dropping Truck returned from yard for Vessel 1
# 545.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 92
# 551.11: After Dropping Truck returned from yard for Vessel 1
# 554.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 91
# 560.11: After Dropping Truck returned from yard for Vessel 1
# 563.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 90
# 569.11: After Dropping Truck returned from yard for Vessel 1
# 572.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 89
# 578.11: After Dropping Truck returned from yard for Vessel 1
# 581.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 88
# 587.11: After Dropping Truck returned from yard for Vessel 1
# 590.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 87
# 596.11: After Dropping Truck returned from yard for Vessel 1
# 599.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 86
# 605.11: After Dropping Truck returned from yard for Vessel 1
# 608.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 85
# 614.11: After Dropping Truck returned from yard for Vessel 1
# 617.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 84
# 623.11: After Dropping Truck returned from yard for Vessel 1
# 626.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 83
# 631.76: Vessel 2 arrived with 150 containers
# 631.76: Vessel 2 berthed
# 631.76: Quay crane assigned to Vessel 2
# 632.11: After Dropping Truck returned from yard for Vessel 1
# 634.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 149
# 635.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 82
# 640.76: After Dropping Truck returned from yard for Vessel 2
# 641.11: After Dropping Truck returned from yard for Vessel 1
# 643.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 148
# 644.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 81
# 649.76: After Dropping Truck returned from yard for Vessel 2
# 650.11: After Dropping Truck returned from yard for Vessel 1
# 652.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 147
# 653.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 80
# 658.76: After Dropping Truck returned from yard for Vessel 2
# 659.11: After Dropping Truck returned from yard for Vessel 1
# 661.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 146
# 662.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 79
# 666.44: Vessel 3 arrived with 150 containers
# 667.76: After Dropping Truck returned from yard for Vessel 2
# 668.11: After Dropping Truck returned from yard for Vessel 1
# 670.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 145
# 671.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 78
# 676.76: After Dropping Truck returned from yard for Vessel 2
# 677.11: After Dropping Truck returned from yard for Vessel 1
# 679.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 144
# 680.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 77
# 685.76: After Dropping Truck returned from yard for Vessel 2
# 686.11: After Dropping Truck returned from yard for Vessel 1
# 688.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 143
# 689.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 76
# 694.76: After Dropping Truck returned from yard for Vessel 2
# 695.11: After Dropping Truck returned from yard for Vessel 1
# 697.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 142
# 698.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 75
# 703.76: After Dropping Truck returned from yard for Vessel 2
# 704.11: After Dropping Truck returned from yard for Vessel 1
# 706.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 141
# 707.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 74
# 712.76: After Dropping Truck returned from yard for Vessel 2
# 713.11: After Dropping Truck returned from yard for Vessel 1
# 715.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 140
# 716.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 73
# 721.76: After Dropping Truck returned from yard for Vessel 2
# 722.11: After Dropping Truck returned from yard for Vessel 1
# 724.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 139
# 725.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 72
# 727.98: Vessel 4 arrived with 150 containers
# 730.76: After Dropping Truck returned from yard for Vessel 2
# 731.11: After Dropping Truck returned from yard for Vessel 1
# 733.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 138
# 734.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 71
# 739.76: After Dropping Truck returned from yard for Vessel 2
# 740.11: After Dropping Truck returned from yard for Vessel 1
# 742.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 137
# 743.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 70
# 748.76: After Dropping Truck returned from yard for Vessel 2
# 749.11: After Dropping Truck returned from yard for Vessel 1
# 751.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 136
# 752.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 69
# 757.76: After Dropping Truck returned from yard for Vessel 2
# 758.11: After Dropping Truck returned from yard for Vessel 1
# 760.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 135
# 761.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 68
# 766.76: After Dropping Truck returned from yard for Vessel 2
# 767.11: After Dropping Truck returned from yard for Vessel 1
# 769.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 134
# 770.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 67
# 775.76: After Dropping Truck returned from yard for Vessel 2
# 776.11: After Dropping Truck returned from yard for Vessel 1
# 778.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 133
# 779.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 66
# 784.76: After Dropping Truck returned from yard for Vessel 2
# 785.11: After Dropping Truck returned from yard for Vessel 1
# 787.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 132
# 788.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 65
# 793.76: After Dropping Truck returned from yard for Vessel 2
# 794.11: After Dropping Truck returned from yard for Vessel 1
# 796.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 131
# 797.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 64
# 802.76: After Dropping Truck returned from yard for Vessel 2
# 803.11: After Dropping Truck returned from yard for Vessel 1
# 805.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 130
# 806.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 63
# 811.76: After Dropping Truck returned from yard for Vessel 2
# 812.11: After Dropping Truck returned from yard for Vessel 1
# 812.54: Vessel 5 arrived with 150 containers
# 814.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 129
# 815.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 62
# 820.76: After Dropping Truck returned from yard for Vessel 2
# 821.11: After Dropping Truck returned from yard for Vessel 1
# 823.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 128
# 824.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 61
# 829.76: After Dropping Truck returned from yard for Vessel 2
# 830.11: After Dropping Truck returned from yard for Vessel 1
# 832.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 127
# 833.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 60
# 838.76: After Dropping Truck returned from yard for Vessel 2
# 839.11: After Dropping Truck returned from yard for Vessel 1
# 841.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 126
# 842.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 59
# 847.76: After Dropping Truck returned from yard for Vessel 2
# 848.11: After Dropping Truck returned from yard for Vessel 1
# 850.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 125
# 851.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 58
# 856.76: After Dropping Truck returned from yard for Vessel 2
# 857.11: After Dropping Truck returned from yard for Vessel 1
# 859.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 124
# 860.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 57
# 865.76: After Dropping Truck returned from yard for Vessel 2
# 866.11: After Dropping Truck returned from yard for Vessel 1
# 868.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 123
# 869.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 56
# 874.76: After Dropping Truck returned from yard for Vessel 2
# 875.11: After Dropping Truck returned from yard for Vessel 1
# 877.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 122
# 878.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 55
# 883.76: After Dropping Truck returned from yard for Vessel 2
# 884.11: After Dropping Truck returned from yard for Vessel 1
# 886.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 121
# 887.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 54
# 892.76: After Dropping Truck returned from yard for Vessel 2
# 893.11: After Dropping Truck returned from yard for Vessel 1
# 895.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 120
# 896.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 53
# 901.76: After Dropping Truck returned from yard for Vessel 2
# 902.11: After Dropping Truck returned from yard for Vessel 1
# 904.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 119
# 905.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 52
# 907.83: Vessel 6 arrived with 150 containers
# 910.76: After Dropping Truck returned from yard for Vessel 2
# 911.11: After Dropping Truck returned from yard for Vessel 1
# 913.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 118
# 914.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 51
# 919.76: After Dropping Truck returned from yard for Vessel 2
# 920.11: After Dropping Truck returned from yard for Vessel 1
# 922.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 117
# 923.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 50
# 928.76: After Dropping Truck returned from yard for Vessel 2
# 929.11: After Dropping Truck returned from yard for Vessel 1
# 931.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 116
# 932.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 49
# 937.76: After Dropping Truck returned from yard for Vessel 2
# 938.11: After Dropping Truck returned from yard for Vessel 1
# 940.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 115
# 941.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 48
# 946.76: After Dropping Truck returned from yard for Vessel 2
# 947.11: After Dropping Truck returned from yard for Vessel 1
# 949.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 114
# 950.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 47
# 955.76: After Dropping Truck returned from yard for Vessel 2
# 956.11: After Dropping Truck returned from yard for Vessel 1
# 958.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 113
# 959.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 46
# 964.76: After Dropping Truck returned from yard for Vessel 2
# 965.11: After Dropping Truck returned from yard for Vessel 1
# 967.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 112
# 968.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 45
# 973.76: After Dropping Truck returned from yard for Vessel 2
# 974.11: After Dropping Truck returned from yard for Vessel 1
# 976.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 111
# 977.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 44
# 982.76: After Dropping Truck returned from yard for Vessel 2
# 983.11: After Dropping Truck returned from yard for Vessel 1
# 985.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 110
# 986.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 43
# 991.76: After Dropping Truck returned from yard for Vessel 2
# 992.11: After Dropping Truck returned from yard for Vessel 1
# 994.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 109
# 995.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 42
# 1000.76: After Dropping Truck returned from yard for Vessel 2
# 1001.11: After Dropping Truck returned from yard for Vessel 1
# 1003.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 108
# 1004.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 41
# 1009.76: After Dropping Truck returned from yard for Vessel 2
# 1010.11: After Dropping Truck returned from yard for Vessel 1
# 1012.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 107
# 1013.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 40
# 1018.76: After Dropping Truck returned from yard for Vessel 2
# 1019.11: After Dropping Truck returned from yard for Vessel 1
# 1021.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 106
# 1022.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 39
# 1027.76: After Dropping Truck returned from yard for Vessel 2
# 1028.11: After Dropping Truck returned from yard for Vessel 1
# 1030.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 105
# 1031.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 38
# 1036.76: After Dropping Truck returned from yard for Vessel 2
# 1037.11: After Dropping Truck returned from yard for Vessel 1
# 1039.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 104
# 1040.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 37
# 1045.76: After Dropping Truck returned from yard for Vessel 2
# 1046.11: After Dropping Truck returned from yard for Vessel 1
# 1048.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 103
# 1049.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 36
# 1054.76: After Dropping Truck returned from yard for Vessel 2
# 1055.11: After Dropping Truck returned from yard for Vessel 1
# 1057.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 102
# 1058.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 35
# 1063.76: After Dropping Truck returned from yard for Vessel 2
# 1064.11: After Dropping Truck returned from yard for Vessel 1
# 1066.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 101
# 1067.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 34
# 1072.76: After Dropping Truck returned from yard for Vessel 2
# 1073.11: After Dropping Truck returned from yard for Vessel 1
# 1075.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 100
# 1076.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 33
# 1081.76: After Dropping Truck returned from yard for Vessel 2
# 1082.11: After Dropping Truck returned from yard for Vessel 1
# 1084.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 99
# 1085.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 32
# 1090.76: After Dropping Truck returned from yard for Vessel 2
# 1091.11: After Dropping Truck returned from yard for Vessel 1
# 1093.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 98
# 1094.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 31
# 1099.76: After Dropping Truck returned from yard for Vessel 2
# 1100.11: After Dropping Truck returned from yard for Vessel 1
# 1102.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 97
# 1103.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 30
# 1108.76: After Dropping Truck returned from yard for Vessel 2
# 1109.11: After Dropping Truck returned from yard for Vessel 1
# 1111.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 96
# 1112.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 29
# 1117.76: After Dropping Truck returned from yard for Vessel 2
# 1118.11: After Dropping Truck returned from yard for Vessel 1
# 1120.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 95
# 1121.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 28
# 1126.76: After Dropping Truck returned from yard for Vessel 2
# 1127.11: After Dropping Truck returned from yard for Vessel 1
# 1129.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 94
# 1130.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 27
# 1135.76: After Dropping Truck returned from yard for Vessel 2
# 1136.11: After Dropping Truck returned from yard for Vessel 1
# 1138.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 93
# 1139.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 26
# 1144.76: After Dropping Truck returned from yard for Vessel 2
# 1145.11: After Dropping Truck returned from yard for Vessel 1
# 1147.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 92
# 1148.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 25
# 1153.76: After Dropping Truck returned from yard for Vessel 2
# 1154.11: After Dropping Truck returned from yard for Vessel 1
# 1156.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 91
# 1157.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 24
# 1162.76: After Dropping Truck returned from yard for Vessel 2
# 1163.11: After Dropping Truck returned from yard for Vessel 1
# 1165.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 90
# 1166.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 23
# 1171.76: After Dropping Truck returned from yard for Vessel 2
# 1172.11: After Dropping Truck returned from yard for Vessel 1
# 1174.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 89
# 1175.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 22
# 1180.76: After Dropping Truck returned from yard for Vessel 2
# 1181.11: After Dropping Truck returned from yard for Vessel 1
# 1183.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 88
# 1184.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 21
# 1189.76: After Dropping Truck returned from yard for Vessel 2
# 1190.11: After Dropping Truck returned from yard for Vessel 1
# 1192.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 87
# 1193.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 20
# 1198.76: After Dropping Truck returned from yard for Vessel 2
# 1199.11: After Dropping Truck returned from yard for Vessel 1
# 1201.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 86
# 1202.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 19
# 1207.76: After Dropping Truck returned from yard for Vessel 2
# 1208.11: After Dropping Truck returned from yard for Vessel 1
# 1210.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 85
# 1211.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 18
# 1216.76: After Dropping Truck returned from yard for Vessel 2
# 1217.11: After Dropping Truck returned from yard for Vessel 1
# 1219.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 84
# 1220.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 17
# 1225.76: After Dropping Truck returned from yard for Vessel 2
# 1226.11: After Dropping Truck returned from yard for Vessel 1
# 1228.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 83
# 1229.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 16
# 1234.76: After Dropping Truck returned from yard for Vessel 2
# 1235.11: After Dropping Truck returned from yard for Vessel 1
# 1237.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 82
# 1238.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 15
# 1243.76: After Dropping Truck returned from yard for Vessel 2
# 1244.11: After Dropping Truck returned from yard for Vessel 1
# 1246.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 81
# 1247.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 14
# 1252.76: After Dropping Truck returned from yard for Vessel 2
# 1253.11: After Dropping Truck returned from yard for Vessel 1
# 1255.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 80
# 1256.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 13
# 1261.76: After Dropping Truck returned from yard for Vessel 2
# 1262.11: After Dropping Truck returned from yard for Vessel 1
# 1264.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 79
# 1265.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 12
# 1270.76: After Dropping Truck returned from yard for Vessel 2
# 1271.11: After Dropping Truck returned from yard for Vessel 1
# 1273.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 78
# 1274.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 11
# 1279.76: After Dropping Truck returned from yard for Vessel 2
# 1280.11: After Dropping Truck returned from yard for Vessel 1
# 1282.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 77
# 1283.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 10
# 1288.76: After Dropping Truck returned from yard for Vessel 2
# 1289.11: After Dropping Truck returned from yard for Vessel 1
# 1291.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 76
# 1292.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 9
# 1297.76: After Dropping Truck returned from yard for Vessel 2
# 1298.11: After Dropping Truck returned from yard for Vessel 1
# 1300.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 75
# 1301.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 8
# 1306.76: After Dropping Truck returned from yard for Vessel 2
# 1307.11: After Dropping Truck returned from yard for Vessel 1
# 1309.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 74
# 1310.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 7
# 1315.76: After Dropping Truck returned from yard for Vessel 2
# 1316.11: After Dropping Truck returned from yard for Vessel 1
# 1318.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 73
# 1319.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 6
# 1324.76: After Dropping Truck returned from yard for Vessel 2
# 1325.11: After Dropping Truck returned from yard for Vessel 1
# 1327.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 72
# 1328.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 5
# 1333.76: After Dropping Truck returned from yard for Vessel 2
# 1334.11: After Dropping Truck returned from yard for Vessel 1
# 1336.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 71
# 1337.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 4
# 1342.76: After Dropping Truck returned from yard for Vessel 2
# 1343.11: After Dropping Truck returned from yard for Vessel 1
# 1345.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 70
# 1346.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 3
# 1351.76: After Dropping Truck returned from yard for Vessel 2
# 1352.11: After Dropping Truck returned from yard for Vessel 1
# 1354.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 69
# 1355.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 2
# 1360.76: After Dropping Truck returned from yard for Vessel 2
# 1361.11: After Dropping Truck returned from yard for Vessel 1
# 1363.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 68
# 1364.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 1
# 1369.76: After Dropping Truck returned from yard for Vessel 2
# 1370.11: After Dropping Truck returned from yard for Vessel 1
# 1372.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 67
# 1373.11: Quay crane moved a container from Vessel 1 to truck. Remaining: 0
# 1378.76: After Dropping Truck returned from yard for Vessel 2
# 1379.11: After Dropping Truck returned from yard for Vessel 1
# 1379.11: Quay crane released for Vessel 1
# 1379.11: Vessel 1 unloaded and departed. Berth is now free.
# 1379.11: Vessel 3 berthed
# 1379.11: Quay crane assigned to Vessel 3
# 1381.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 66
# 1382.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 149
# 1387.76: After Dropping Truck returned from yard for Vessel 2
# 1388.11: After Dropping Truck returned from yard for Vessel 3
# 1390.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 65
# 1391.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 148
# 1396.76: After Dropping Truck returned from yard for Vessel 2
# 1397.11: After Dropping Truck returned from yard for Vessel 3
# 1399.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 64
# 1400.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 147
# 1405.76: After Dropping Truck returned from yard for Vessel 2
# 1406.11: After Dropping Truck returned from yard for Vessel 3
# 1408.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 63
# 1409.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 146
# 1414.76: After Dropping Truck returned from yard for Vessel 2
# 1415.11: After Dropping Truck returned from yard for Vessel 3
# 1417.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 62
# 1418.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 145
# 1423.76: After Dropping Truck returned from yard for Vessel 2
# 1424.11: After Dropping Truck returned from yard for Vessel 3
# 1426.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 61
# 1427.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 144
# 1432.76: After Dropping Truck returned from yard for Vessel 2
# 1433.11: After Dropping Truck returned from yard for Vessel 3
# 1435.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 60
# 1436.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 143
# 1441.76: After Dropping Truck returned from yard for Vessel 2
# 1442.11: After Dropping Truck returned from yard for Vessel 3
# 1444.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 59
# 1445.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 142
# 1450.76: After Dropping Truck returned from yard for Vessel 2
# 1451.11: After Dropping Truck returned from yard for Vessel 3
# 1453.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 58
# 1454.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 141
# 1459.76: After Dropping Truck returned from yard for Vessel 2
# 1460.11: After Dropping Truck returned from yard for Vessel 3
# 1462.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 57
# 1463.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 140
# 1468.76: After Dropping Truck returned from yard for Vessel 2
# 1469.11: After Dropping Truck returned from yard for Vessel 3
# 1471.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 56
# 1472.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 139
# 1477.76: After Dropping Truck returned from yard for Vessel 2
# 1478.11: After Dropping Truck returned from yard for Vessel 3
# 1480.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 55
# 1481.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 138
# 1486.76: After Dropping Truck returned from yard for Vessel 2
# 1487.11: After Dropping Truck returned from yard for Vessel 3
# 1489.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 54
# 1490.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 137
# 1495.76: After Dropping Truck returned from yard for Vessel 2
# 1496.11: After Dropping Truck returned from yard for Vessel 3
# 1498.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 53
# 1499.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 136
# 1504.76: After Dropping Truck returned from yard for Vessel 2
# 1505.11: After Dropping Truck returned from yard for Vessel 3
# 1507.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 52
# 1508.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 135
# 1513.76: After Dropping Truck returned from yard for Vessel 2
# 1514.11: After Dropping Truck returned from yard for Vessel 3
# 1516.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 51
# 1517.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 134
# 1522.76: After Dropping Truck returned from yard for Vessel 2
# 1523.11: After Dropping Truck returned from yard for Vessel 3
# 1525.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 50
# 1526.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 133
# 1531.76: After Dropping Truck returned from yard for Vessel 2
# 1532.11: After Dropping Truck returned from yard for Vessel 3
# 1534.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 49
# 1535.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 132
# 1540.76: After Dropping Truck returned from yard for Vessel 2
# 1541.11: After Dropping Truck returned from yard for Vessel 3
# 1543.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 48
# 1544.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 131
# 1549.76: After Dropping Truck returned from yard for Vessel 2
# 1550.11: After Dropping Truck returned from yard for Vessel 3
# 1552.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 47
# 1553.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 130
# 1558.76: After Dropping Truck returned from yard for Vessel 2
# 1559.11: After Dropping Truck returned from yard for Vessel 3
# 1561.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 46
# 1562.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 129
# 1567.76: After Dropping Truck returned from yard for Vessel 2
# 1568.11: After Dropping Truck returned from yard for Vessel 3
# 1570.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 45
# 1571.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 128
# 1576.76: After Dropping Truck returned from yard for Vessel 2
# 1577.11: After Dropping Truck returned from yard for Vessel 3
# 1579.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 44
# 1580.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 127
# 1585.76: After Dropping Truck returned from yard for Vessel 2
# 1586.11: After Dropping Truck returned from yard for Vessel 3
# 1588.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 43
# 1589.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 126
# 1594.76: After Dropping Truck returned from yard for Vessel 2
# 1595.11: After Dropping Truck returned from yard for Vessel 3
# 1597.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 42
# 1598.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 125
# 1603.76: After Dropping Truck returned from yard for Vessel 2
# 1604.11: After Dropping Truck returned from yard for Vessel 3
# 1606.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 41
# 1607.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 124
# 1612.76: After Dropping Truck returned from yard for Vessel 2
# 1613.11: After Dropping Truck returned from yard for Vessel 3
# 1615.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 40
# 1616.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 123
# 1621.76: After Dropping Truck returned from yard for Vessel 2
# 1622.11: After Dropping Truck returned from yard for Vessel 3
# 1624.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 39
# 1625.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 122
# 1630.76: After Dropping Truck returned from yard for Vessel 2
# 1631.11: After Dropping Truck returned from yard for Vessel 3
# 1633.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 38
# 1634.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 121
# 1639.76: After Dropping Truck returned from yard for Vessel 2
# 1640.11: After Dropping Truck returned from yard for Vessel 3
# 1642.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 37
# 1643.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 120
# 1648.76: After Dropping Truck returned from yard for Vessel 2
# 1649.11: After Dropping Truck returned from yard for Vessel 3
# 1651.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 36
# 1652.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 119
# 1652.12: Vessel 7 arrived with 150 containers
# 1657.76: After Dropping Truck returned from yard for Vessel 2
# 1658.11: After Dropping Truck returned from yard for Vessel 3
# 1660.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 35
# 1661.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 118
# 1666.76: After Dropping Truck returned from yard for Vessel 2
# 1667.11: After Dropping Truck returned from yard for Vessel 3
# 1669.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 34
# 1670.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 117
# 1675.76: After Dropping Truck returned from yard for Vessel 2
# 1676.11: After Dropping Truck returned from yard for Vessel 3
# 1678.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 33
# 1679.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 116
# 1684.76: After Dropping Truck returned from yard for Vessel 2
# 1685.11: After Dropping Truck returned from yard for Vessel 3
# 1687.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 32
# 1688.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 115
# 1693.76: After Dropping Truck returned from yard for Vessel 2
# 1694.11: After Dropping Truck returned from yard for Vessel 3
# 1696.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 31
# 1697.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 114
# 1702.76: After Dropping Truck returned from yard for Vessel 2
# 1703.11: After Dropping Truck returned from yard for Vessel 3
# 1705.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 30
# 1706.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 113
# 1711.76: After Dropping Truck returned from yard for Vessel 2
# 1712.11: After Dropping Truck returned from yard for Vessel 3
# 1714.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 29
# 1715.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 112
# 1720.76: After Dropping Truck returned from yard for Vessel 2
# 1721.11: After Dropping Truck returned from yard for Vessel 3
# 1723.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 28
# 1724.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 111
# 1729.76: After Dropping Truck returned from yard for Vessel 2
# 1730.11: After Dropping Truck returned from yard for Vessel 3
# 1732.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 27
# 1733.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 110
# 1738.76: After Dropping Truck returned from yard for Vessel 2
# 1739.11: After Dropping Truck returned from yard for Vessel 3
# 1741.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 26
# 1742.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 109
# 1747.76: After Dropping Truck returned from yard for Vessel 2
# 1748.11: After Dropping Truck returned from yard for Vessel 3
# 1750.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 25
# 1751.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 108
# 1756.76: After Dropping Truck returned from yard for Vessel 2
# 1757.11: After Dropping Truck returned from yard for Vessel 3
# 1759.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 24
# 1760.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 107
# 1765.76: After Dropping Truck returned from yard for Vessel 2
# 1766.11: After Dropping Truck returned from yard for Vessel 3
# 1768.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 23
# 1769.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 106
# 1774.76: After Dropping Truck returned from yard for Vessel 2
# 1775.11: After Dropping Truck returned from yard for Vessel 3
# 1777.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 22
# 1778.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 105
# 1783.76: After Dropping Truck returned from yard for Vessel 2
# 1784.11: After Dropping Truck returned from yard for Vessel 3
# 1786.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 21
# 1787.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 104
# 1792.76: After Dropping Truck returned from yard for Vessel 2
# 1793.11: After Dropping Truck returned from yard for Vessel 3
# 1795.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 20
# 1796.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 103
# 1801.76: After Dropping Truck returned from yard for Vessel 2
# 1802.11: After Dropping Truck returned from yard for Vessel 3
# 1804.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 19
# 1805.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 102
# 1810.76: After Dropping Truck returned from yard for Vessel 2
# 1811.11: After Dropping Truck returned from yard for Vessel 3
# 1813.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 18
# 1814.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 101
# 1819.76: After Dropping Truck returned from yard for Vessel 2
# 1820.11: After Dropping Truck returned from yard for Vessel 3
# 1822.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 17
# 1823.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 100
# 1828.76: After Dropping Truck returned from yard for Vessel 2
# 1829.11: After Dropping Truck returned from yard for Vessel 3
# 1831.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 16
# 1832.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 99
# 1837.76: After Dropping Truck returned from yard for Vessel 2
# 1838.11: After Dropping Truck returned from yard for Vessel 3
# 1840.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 15
# 1841.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 98
# 1846.76: After Dropping Truck returned from yard for Vessel 2
# 1847.11: After Dropping Truck returned from yard for Vessel 3
# 1849.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 14
# 1850.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 97
# 1855.76: After Dropping Truck returned from yard for Vessel 2
# 1856.11: After Dropping Truck returned from yard for Vessel 3
# 1858.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 13
# 1859.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 96
# 1864.76: After Dropping Truck returned from yard for Vessel 2
# 1865.11: After Dropping Truck returned from yard for Vessel 3
# 1867.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 12
# 1868.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 95
# 1873.76: After Dropping Truck returned from yard for Vessel 2
# 1874.11: After Dropping Truck returned from yard for Vessel 3
# 1876.76: Quay crane moved a container from Vessel 2 to truck. Remaining: 11
# ...
# 2489.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 26
# 2494.76: After Dropping Truck returned from yard for Vessel 4
# 2495.11: After Dropping Truck returned from yard for Vessel 3
# 2497.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 92
# 2498.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 25
# 2503.76: After Dropping Truck returned from yard for Vessel 4
# 2504.11: After Dropping Truck returned from yard for Vessel 3
# 2506.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 91
# 2507.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 24
# 2512.76: After Dropping Truck returned from yard for Vessel 4
# 2513.11: After Dropping Truck returned from yard for Vessel 3
# 2515.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 90
# 2516.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 23
# 2521.76: After Dropping Truck returned from yard for Vessel 4
# 2522.11: After Dropping Truck returned from yard for Vessel 3
# 2524.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 89
# 2525.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 22
# 2530.76: After Dropping Truck returned from yard for Vessel 4
# 2531.11: After Dropping Truck returned from yard for Vessel 3
# 2533.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 88
# 2534.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 21
# 2539.76: After Dropping Truck returned from yard for Vessel 4
# 2540.11: After Dropping Truck returned from yard for Vessel 3
# 2542.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 87
# 2543.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 20
# 2548.76: After Dropping Truck returned from yard for Vessel 4
# 2549.11: After Dropping Truck returned from yard for Vessel 3
# 2551.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 86
# 2552.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 19
# 2557.76: After Dropping Truck returned from yard for Vessel 4
# 2558.11: After Dropping Truck returned from yard for Vessel 3
# 2560.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 85
# 2561.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 18
# 2566.76: After Dropping Truck returned from yard for Vessel 4
# 2567.11: After Dropping Truck returned from yard for Vessel 3
# 2569.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 84
# 2570.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 17
# 2575.76: After Dropping Truck returned from yard for Vessel 4
# 2576.11: After Dropping Truck returned from yard for Vessel 3
# 2578.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 83
# 2579.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 16
# 2584.76: After Dropping Truck returned from yard for Vessel 4
# 2585.11: After Dropping Truck returned from yard for Vessel 3
# 2587.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 82
# 2588.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 15
# 2593.76: After Dropping Truck returned from yard for Vessel 4
# 2594.11: After Dropping Truck returned from yard for Vessel 3
# 2596.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 81
# 2597.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 14
# 2602.76: After Dropping Truck returned from yard for Vessel 4
# 2603.11: After Dropping Truck returned from yard for Vessel 3
# 2605.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 80
# 2606.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 13
# 2611.76: After Dropping Truck returned from yard for Vessel 4
# 2612.11: After Dropping Truck returned from yard for Vessel 3
# 2614.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 79
# 2615.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 12
# 2620.76: After Dropping Truck returned from yard for Vessel 4
# 2621.11: After Dropping Truck returned from yard for Vessel 3
# 2623.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 78
# 2624.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 11
# 2629.76: After Dropping Truck returned from yard for Vessel 4
# 2630.11: After Dropping Truck returned from yard for Vessel 3
# 2632.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 77
# 2633.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 10
# 2634.96: Vessel 10 arrived with 150 containers
# 2638.76: After Dropping Truck returned from yard for Vessel 4
# 2639.11: After Dropping Truck returned from yard for Vessel 3
# 2641.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 76
# 2642.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 9
# 2647.76: After Dropping Truck returned from yard for Vessel 4
# 2648.11: After Dropping Truck returned from yard for Vessel 3
# 2650.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 75
# 2651.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 8
# 2656.76: After Dropping Truck returned from yard for Vessel 4
# 2657.11: After Dropping Truck returned from yard for Vessel 3
# 2659.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 74
# 2660.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 7
# 2665.76: After Dropping Truck returned from yard for Vessel 4
# 2666.11: After Dropping Truck returned from yard for Vessel 3
# 2668.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 73
# 2669.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 6
# 2674.76: After Dropping Truck returned from yard for Vessel 4
# 2675.11: After Dropping Truck returned from yard for Vessel 3
# 2677.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 72
# 2678.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 5
# 2683.76: After Dropping Truck returned from yard for Vessel 4
# 2684.11: After Dropping Truck returned from yard for Vessel 3
# 2686.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 71
# 2687.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 4
# 2692.76: After Dropping Truck returned from yard for Vessel 4
# 2693.11: After Dropping Truck returned from yard for Vessel 3
# 2695.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 70
# 2696.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 3
# 2701.76: After Dropping Truck returned from yard for Vessel 4
# 2702.11: After Dropping Truck returned from yard for Vessel 3
# 2704.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 69
# 2705.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 2
# 2707.68: Vessel 11 arrived with 150 containers
# 2710.76: After Dropping Truck returned from yard for Vessel 4
# 2711.11: After Dropping Truck returned from yard for Vessel 3
# 2713.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 68
# 2714.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 1
# 2719.76: After Dropping Truck returned from yard for Vessel 4
# 2720.11: After Dropping Truck returned from yard for Vessel 3
# 2722.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 67
# 2723.11: Quay crane moved a container from Vessel 3 to truck. Remaining: 0
# 2728.76: After Dropping Truck returned from yard for Vessel 4
# 2729.11: After Dropping Truck returned from yard for Vessel 3
# 2729.11: Quay crane released for Vessel 3
# 2729.11: Vessel 3 unloaded and departed. Berth is now free.
# 2729.11: Vessel 5 berthed
# 2729.11: Quay crane assigned to Vessel 5
# 2731.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 66
# 2732.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 149
# 2737.76: After Dropping Truck returned from yard for Vessel 4
# 2738.11: After Dropping Truck returned from yard for Vessel 5
# 2740.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 65
# 2741.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 148
# 2746.76: After Dropping Truck returned from yard for Vessel 4
# 2747.11: After Dropping Truck returned from yard for Vessel 5
# 2749.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 64
# 2750.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 147
# 2755.76: After Dropping Truck returned from yard for Vessel 4
# 2756.11: After Dropping Truck returned from yard for Vessel 5
# 2758.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 63
# 2759.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 146
# 2764.76: After Dropping Truck returned from yard for Vessel 4
# 2765.11: After Dropping Truck returned from yard for Vessel 5
# 2767.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 62
# 2768.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 145
# 2773.76: After Dropping Truck returned from yard for Vessel 4
# 2774.11: After Dropping Truck returned from yard for Vessel 5
# 2776.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 61
# 2777.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 144
# 2782.76: After Dropping Truck returned from yard for Vessel 4
# 2783.11: After Dropping Truck returned from yard for Vessel 5
# 2785.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 60
# 2786.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 143
# 2791.76: After Dropping Truck returned from yard for Vessel 4
# 2792.11: After Dropping Truck returned from yard for Vessel 5
# 2794.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 59
# 2795.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 142
# 2800.76: After Dropping Truck returned from yard for Vessel 4
# 2801.11: After Dropping Truck returned from yard for Vessel 5
# 2803.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 58
# 2804.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 141
# 2809.76: After Dropping Truck returned from yard for Vessel 4
# 2810.11: After Dropping Truck returned from yard for Vessel 5
# 2812.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 57
# 2813.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 140
# 2818.76: After Dropping Truck returned from yard for Vessel 4
# 2819.11: After Dropping Truck returned from yard for Vessel 5
# 2821.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 56
# 2822.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 139
# 2827.76: After Dropping Truck returned from yard for Vessel 4
# 2828.11: After Dropping Truck returned from yard for Vessel 5
# 2830.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 55
# 2831.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 138
# 2836.76: After Dropping Truck returned from yard for Vessel 4
# 2837.11: After Dropping Truck returned from yard for Vessel 5
# 2839.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 54
# 2840.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 137
# 2845.76: After Dropping Truck returned from yard for Vessel 4
# 2846.11: After Dropping Truck returned from yard for Vessel 5
# 2848.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 53
# 2849.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 136
# 2854.76: After Dropping Truck returned from yard for Vessel 4
# 2855.11: After Dropping Truck returned from yard for Vessel 5
# 2857.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 52
# 2858.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 135
# 2863.76: After Dropping Truck returned from yard for Vessel 4
# 2864.11: After Dropping Truck returned from yard for Vessel 5
# 2866.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 51
# 2867.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 134
# 2872.76: After Dropping Truck returned from yard for Vessel 4
# 2873.11: After Dropping Truck returned from yard for Vessel 5
# 2875.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 50
# 2876.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 133
# 2881.76: After Dropping Truck returned from yard for Vessel 4
# 2882.11: After Dropping Truck returned from yard for Vessel 5
# 2884.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 49
# 2885.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 132
# 2890.76: After Dropping Truck returned from yard for Vessel 4
# 2891.11: After Dropping Truck returned from yard for Vessel 5
# 2893.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 48
# 2894.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 131
# 2899.76: After Dropping Truck returned from yard for Vessel 4
# 2900.11: After Dropping Truck returned from yard for Vessel 5
# 2902.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 47
# 2903.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 130
# 2908.76: After Dropping Truck returned from yard for Vessel 4
# 2909.11: After Dropping Truck returned from yard for Vessel 5
# 2911.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 46
# 2912.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 129
# 2917.76: After Dropping Truck returned from yard for Vessel 4
# 2918.11: After Dropping Truck returned from yard for Vessel 5
# 2920.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 45
# 2921.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 128
# 2926.76: After Dropping Truck returned from yard for Vessel 4
# 2927.11: After Dropping Truck returned from yard for Vessel 5
# 2929.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 44
# 2930.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 127
# 2935.76: After Dropping Truck returned from yard for Vessel 4
# 2936.11: After Dropping Truck returned from yard for Vessel 5
# 2938.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 43
# 2939.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 126
# 2944.76: After Dropping Truck returned from yard for Vessel 4
# 2945.11: After Dropping Truck returned from yard for Vessel 5
# 2947.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 42
# 2948.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 125
# 2953.76: After Dropping Truck returned from yard for Vessel 4
# 2954.11: After Dropping Truck returned from yard for Vessel 5
# 2956.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 41
# 2957.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 124
# 2962.76: After Dropping Truck returned from yard for Vessel 4
# 2963.11: After Dropping Truck returned from yard for Vessel 5
# 2965.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 40
# 2966.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 123
# 2971.76: After Dropping Truck returned from yard for Vessel 4
# 2972.11: After Dropping Truck returned from yard for Vessel 5
# 2974.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 39
# 2975.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 122
# 2980.76: After Dropping Truck returned from yard for Vessel 4
# 2981.11: After Dropping Truck returned from yard for Vessel 5
# 2983.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 38
# 2984.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 121
# 2989.76: After Dropping Truck returned from yard for Vessel 4
# 2990.11: After Dropping Truck returned from yard for Vessel 5
# 2992.76: Quay crane moved a container from Vessel 4 to truck. Remaining: 37
# 2993.11: Quay crane moved a container from Vessel 5 to truck. Remaining: 120
# 2998.76: After Dropping Truck returned from yard for Vessel 4
# 2999.11: After Dropping Truck returned from yard for Vessel 5
# 3000.00: Simulation completed
